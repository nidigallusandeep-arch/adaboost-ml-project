# %% [markdown]
# # Classification

# %%
from sklearn.datasets import load_iris
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report

# %% [markdown]
# # Load Iris dataset

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %% [markdown]
# # split into train and test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,train_size=0.8,random_state=42)

# %%
# base weak learner(shallow tree)
base_estimator=DecisionTreeClassifier(max_depth=1)

# %% [markdown]
# # Create AdaBoost model

# %%
base_estimator = DecisionTreeClassifier(max_depth=1)
ada_clf = AdaBoostClassifier(
    estimator=base_estimator,
    n_estimators=50,
    learning_rate=1.0,
    random_state=42)
ada_clf.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=1),
#                    random_state=42)

# %% [markdown]
# # Predictions and evaluation

# %%
y_pred = ada_clf.predict(X_test)

# %%
print("Accuracy:",accuracy_score(y_test,y_pred))
# Out:
# Accuracy: 0.9333333333333333

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.89      0.89      0.89         9
#            2       0.91      0.91      0.91        11
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.93      0.93        30
# weighted avg       0.93      0.93      0.93        30

# %% [markdown]
# # Regreesion Using Adaptive Boosting

# %%
from sklearn.datasets import fetch_california_housing # use load_diabetes dat
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,r2_score

# %% [markdown]
# # load california housing datasete

# %%
data=fetch_california_housing()
X,y=data.data,data.target

# %% [markdown]
# # train test split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.2,random_state=42)

# %%
base_estimator = DecisionTreeRegressor(max_depth=4)
ada_reg = AdaBoostRegressor(estimator=base_estimator,
                            n_estimators=100,
                            learning_rate=0.5,
                            random_state=42)
ada_reg.fit(X_train, y_train)
# Out:
# AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=4),
#                   learning_rate=0.5, n_estimators=100, random_state=42)

# %% [markdown]
# # Predictions

# %%
y_pred = ada_reg.predict(X_test)

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import mean_squared_error
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# Mean Squared Error: 0.6075090104514739
# R² Score: 0.5425169128298795
